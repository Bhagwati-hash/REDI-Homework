# %% [markdown]
# #### Hi! Today you will play with NaN values and another Data Manipulation methods. Let us know if you need help and also if you need more challenges on that :)

# %% [markdown]
# #### The dataset that you will use is again recipes.csv. You can either use your own or the one in the subfolder "data". Do not forget to import the necessary libraries!

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("data\\recipes.csv")
df.head(5)
# Out:
#    Unnamed: 0  vegetarian  glutenFree  dairyFree  veryHealthy  healthScore  \
# 0           0        True        True       True        False          1.0
# 1           1        True        True      False        False          0.0
# 2           2       False       False      False        False          3.0
# 3           3        True       False       True        False          2.0
# 4           4       False        True      False        False         31.0
#
#    aggregateLikes      id                                    title  \
# 0               3  633998                Banana Blueberry Pancakes
# 1               1  634426  Basil and Orange Confit Compound Butter
# 2               1  635085                 Black Bottom Banana Bars
# 3               1  663229      The Best Raw Chocolate Chip Cookies
# 4               3  651437      Mediterranean Spinach Artichoke Dip
#
#    pricePerServing  ...  VitaminB3Amount  VitaminB3percentOfDailyNeed  \
# 0            55.79  ...             0.49                         2.44
# 1            15.07  ...              NaN                          NaN
# 2            78.85  ...             2.63                        13.13
# 3            54.64  ...             0.65                         3.26
# 4           115.26  ...             0.66                         3.29
#
#   VitaminB1Amount  VitaminB1percentOfDailyNeed  CalciumAmount  \
# 0            0.03                         2.26          18.11
# 1             NaN                          NaN            NaN
# 2            0.32                        21.09         100.80
# 3            0.10                         6.47          26.79
# 4            0.07                         4.64         162.84
#
#    CalciumpercentOfDailyNeed  AlcoholAmount  AlcoholpercentOfDailyNeed  \
# 0                       1.81            NaN                        NaN
# 1                        NaN            NaN                        NaN
# 2                      10.08           0.28                       1.53
# 3                       2.68            NaN                        NaN
# 4                      16.28            NaN                        NaN
#
#    CaffeineAmount  CaffeinepercentOfDailyNeed
# 0             NaN                         NaN
# 1             NaN                         NaN
# 2            9.89                         3.3
# 3             NaN                         NaN
# 4             NaN                         NaN
#
# [5 rows x 79 columns]

# %% [markdown]
# #### Print the names of Columns that have null values

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['FiberAmount', 'FiberpercentOfDailyNeed', 'VitaminB6Amount',
#        'VitaminB6percentOfDailyNeed', 'ManganeseAmount',
#        'ManganesepercentOfDailyNeed', 'SeleniumAmount',
#        'SeleniumpercentOfDailyNeed', 'PotassiumAmount',
#        'PotassiumpercentOfDailyNeed', 'VitaminB2Amount',
#        'VitaminB2percentOfDailyNeed', 'VitaminCAmount',
#        'VitaminCpercentOfDailyNeed', 'PhosphorusAmount',
#        'PhosphoruspercentOfDailyNeed', 'FolateAmount',
#        'FolatepercentOfDailyNeed', 'VitaminB5Amount',
#        'VitaminB5percentOfDailyNeed', 'MagnesiumAmount',
#        'MagnesiumpercentOfDailyNeed', 'IronAmount', 'IronpercentOfDailyNeed',
#        'VitaminKAmount', 'VitaminKpercentOfDailyNeed', 'CopperAmount',
#        'CopperpercentOfDailyNeed', 'VitaminAAmount',
#        'VitaminApercentOfDailyNeed', 'VitaminB12Amount',
#        'VitaminB12percentOfDailyNeed', 'VitaminDAmount',
#        'VitaminDpercentOfDailyNeed', 'ZincAmount', 'ZincpercentOfDailyNeed',
#        'VitaminEAmount', 'VitaminEpercentOfDailyNeed', 'VitaminB3Amount',
#        'VitaminB3percentOfDailyNeed', 'VitaminB1Amount',
#        'VitaminB1percentOfDailyNeed', 'CalciumAmount',
#        'CalciumpercentOfDailyNeed', 'AlcoholAmount',
#        'AlcoholpercentOfDailyNeed', 'CaffeineAmount',
#        'CaffeinepercentOfDailyNeed'],
#       dtype='object')

# %% [markdown]
# #### Print the recipes with the highest number of aggregateLikes

# %%
df.sort_values("aggregateLikes",ascending=False).iloc[0,:].title
# Out:
# 'Slow Cooker Spicy Hot Wings'

# %% [markdown]
# #### Handle the missing values of “calcium percent of Daily need”. Sort the resulting DataFrame by id column.

# %%
df.sort_values(by="id",inplace=True)

# %% [markdown]
# #### Delete the columns that have null values == 141

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 83 to 67
# Data columns (total 79 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          150 non-null    int64
#  1   vegetarian                          150 non-null    bool
#  2   glutenFree                          150 non-null    bool
#  3   dairyFree                           150 non-null    bool
#  4   veryHealthy                         150 non-null    bool
#  5   healthScore                         150 non-null    float64
#  6   aggregateLikes                      150 non-null    int64
#  7   id                                  150 non-null    int64
#  8   title                               150 non-null    object
#  9   pricePerServing                     150 non-null    float64
#  10  readyInMinutes                      150 non-null    int64
#  11  servings                            150 non-null    int64
#  12  sourceUrl                           150 non-null    object
#  13  CaloriesAmount                      150 non-null    float64
#  14  CaloriespercentOfDailyNeed          150 non-null    float64
#  15  FatAmount                           150 non-null    float64
#  16  FatpercentOfDailyNeed               150 non-null    float64
#  17  SaturatedFatAmount                  150 non-null    float64
#  18  SaturatedFatpercentOfDailyNeed      150 non-null    float64
#  19  CarbohydratesAmount                 150 non-null    float64
#  20  CarbohydratespercentOfDailyNeed     150 non-null    float64
#  21  NetCarbohydratesAmount              150 non-null    float64
#  22  NetCarbohydratespercentOfDailyNeed  150 non-null    float64
#  23  SugarAmount                         150 non-null    float64
#  24  SugarpercentOfDailyNeed             150 non-null    float64
#  25  CholesterolAmount                   150 non-null    float64
#  26  CholesterolpercentOfDailyNeed       150 non-null    float64
#  27  SodiumAmount                        150 non-null    float64
#  28  SodiumpercentOfDailyNeed            150 non-null    float64
#  29  ProteinAmount                       150 non-null    float64
#  30  ProteinpercentOfDailyNeed           150 non-null    float64
#  31  FiberAmount                         142 non-null    float64
#  32  FiberpercentOfDailyNeed             142 non-null    float64
#  33  VitaminB6Amount                     140 non-null    float64
#  34  VitaminB6percentOfDailyNeed         140 non-null    float64
#  35  ManganeseAmount                     146 non-null    float64
#  36  ManganesepercentOfDailyNeed         146 non-null    float64
#  37  SeleniumAmount                      134 non-null    float64
#  38  SeleniumpercentOfDailyNeed          134 non-null    float64
#  39  PotassiumAmount                     143 non-null    float64
#  40  PotassiumpercentOfDailyNeed         143 non-null    float64
#  41  VitaminB2Amount                     146 non-null    float64
#  42  VitaminB2percentOfDailyNeed         146 non-null    float64
#  43  VitaminCAmount                      119 non-null    float64
#  44  VitaminCpercentOfDailyNeed          119 non-null    float64
#  45  PhosphorusAmount                    147 non-null    float64
#  46  PhosphoruspercentOfDailyNeed        147 non-null    float64
#  47  FolateAmount                        144 non-null    float64
#  48  FolatepercentOfDailyNeed            144 non-null    float64
#  49  VitaminB5Amount                     136 non-null    float64
#  50  VitaminB5percentOfDailyNeed         136 non-null    float64
#  51  MagnesiumAmount                     142 non-null    float64
#  52  MagnesiumpercentOfDailyNeed         142 non-null    float64
#  53  IronAmount                          147 non-null    float64
#  54  IronpercentOfDailyNeed              147 non-null    float64
#  55  VitaminKAmount                      138 non-null    float64
#  56  VitaminKpercentOfDailyNeed          138 non-null    float64
#  57  CopperAmount                        144 non-null    float64
#  58  CopperpercentOfDailyNeed            144 non-null    float64
#  59  VitaminAAmount                      137 non-null    float64
#  60  VitaminApercentOfDailyNeed          137 non-null    float64
#  61  VitaminB12Amount                    93 non-null     float64
#  62  VitaminB12percentOfDailyNeed        93 non-null     float64
#  63  VitaminDAmount                      75 non-null     float64
#  64  VitaminDpercentOfDailyNeed          75 non-null     float64
#  65  ZincAmount                          139 non-null    float64
#  66  ZincpercentOfDailyNeed              139 non-null    float64
#  67  VitaminEAmount                      138 non-null    float64
#  68  VitaminEpercentOfDailyNeed          138 non-null    float64
#  69  VitaminB3Amount                     139 non-null    float64
#  70  VitaminB3percentOfDailyNeed         139 non-null    float64
#  71  VitaminB1Amount                     143 non-null    float64
#  72  VitaminB1percentOfDailyNeed         143 non-null    float64
#  73  CalciumAmount                       142 non-null    float64
#  74  CalciumpercentOfDailyNeed           142 non-null    float64
#  75  AlcoholAmount                       21 non-null     float64
#  76  AlcoholpercentOfDailyNeed           21 non-null     float64
#  77  CaffeineAmount                      9 non-null      float64
#  78  CaffeinepercentOfDailyNeed          9 non-null      float64
# dtypes: bool(4), float64(68), int64(5), object(2)
# memory usage: 89.6+ KB

# %% [markdown]
# #### Print the title of the recipes that are vegetarian == TRUE and glutenFree == True

# %%
maskv=df.vegetarian
maskg=df.glutenFree
df[maskv&maskg]
# Out:
#      Unnamed: 0  vegetarian  glutenFree  dairyFree  veryHealthy  healthScore  \
# 0             0        True        True       True        False          1.0
# 1             1        True        True      False        False          0.0
# 85           85        True        True      False        False          5.0
# 100         100        True        True      False        False          7.0
# 107         107        True        True       True        False          3.0
# 96           96        True        True      False        False          4.0
# 22           22        True        True      False        False         16.0
# 147         147        True        True       True         True         93.0
# 132         132        True        True      False        False         16.0
# 101         101        True        True       True        False         10.0
# 33           33        True        True       True        False         54.0
# 27           27        True        True      False        False         19.0
# 72           72        True        True       True        False         49.0
# 20           20        True        True       True        False         20.0
# 119         119        True        True       True        False         30.0
# 24           24        True        True      False        False          6.0
# 149         149        True        True       True         True        100.0
# 106         106        True        True       True        False          7.0
# 29           29        True        True       True        False         19.0
# 139         139        True        True      False        False         37.0
# 80           80        True        True      False         True         61.0
# 131         131        True        True      False        False          7.0
# 15           15        True        True      False        False          8.0
# 42           42        True        True      False        False          2.0
# 97           97        True        True       True        False          2.0
# 37           37        True        True      False        False         17.0
# 93           93        True        True       True        False          4.0
# 148         148        True        True      False        False          5.0
# 57           57        True        True      False        False          5.0
# 123         123        True        True       True         True        100.0
# 14           14        True        True       True        False         16.0
# 143         143        True        True       True        False         50.0
# 133         133        True        True       True        False          7.0
# 69           69        True        True       True        False         11.0
# 31           31        True        True      False        False          5.0
# 61           61        True        True       True        False         13.0
# 102         102        True        True       True        False          1.0
# 129         129        True        True       True        False         14.0
# 126         126        True        True       True        False         21.0
# 134         134        True        True       True         True         77.0
# 30           30        True        True       True        False         17.0
# 39           39        True        True       True        False          7.0
#
#      aggregateLikes       id  \
# 0                 3   633998
# 1                 1   634426
# 85                1   634798
# 100               1   635290
# 107               1   635495
# 96                1   636062
# 22                1   636600
# 147               2   637297
# 132               1   637705
# 101             103   641227
# 33                2   641443
# 27                2   641962
# 72                1   642154
# 20                1   642892
# 119               1   643674
# 24                7   645416
# 149               4   647875
# 106               1   648467
# 29                1   648742
# 139               1   649354
# 80                1   650484
# 131               1   650772
# 15                1   653399
# 42                8   655098
# 97                1   655282
# 37                1   658495
# 93                2   658665
# 148               1   659412
# 57                1   659412
# 123               1   659689
# 14                2   661036
# 143               6   661653
# 133               6   663313
# 69                0   673436
# 31              249   716421
# 61                1  1095692
# 102               1  1095713
# 129               1  1096178
# 126               1  1096231
# 134               1  1096268
# 30                1  1096306
# 39                6  1098357
#
#                                                  title  pricePerServing  ...  \
# 0                            Banana Blueberry Pancakes            55.79  ...
# 1              Basil and Orange Confit Compound Butter            15.07  ...
# 85                                           Beet Slaw           104.01  ...
# 100                                Blender Carrot Soup            57.73  ...
# 107                         Blueberry Mojito Popsicles           114.86  ...
# 96                                  Breakfast Porridge           121.34  ...
# 22                               Butternut Squash Soup           102.10  ...
# 147                          Cauliflower Chickpea Stew           139.28  ...
# 132                        Cherries and Yogurt Parfait           277.28  ...
# 101                                    Dandelion pesto           132.51  ...
# 33                           Detox Orange Carrot Juice           104.27  ...
# 27                              Easy Eggplant Parmesan           195.51  ...
# 72                           EASY, CUMIN-LENTIL SPREAD            29.56  ...
# 20                         Fire Roasted Tomato Chutney            74.69  ...
# 119                                   Fried Brown Rice           188.92  ...
# 24                       Green Beans with Garlic Chips            83.90  ...
# 149        Indian-Style Dill and Turmeric Potato Salad           117.24  ...
# 106                            Japanese Cucumber Salad            29.96  ...
# 29                                          Kappa Maki            72.94  ...
# 139                                Layered Greek Salad           123.12  ...
# 80                               Luscious Palak Paneer           557.85  ...
# 131                            Mango Cranberry Sherbet           144.10  ...
# 15                                          Nutty Rice            99.58  ...
# 42                             Peach Coconut Ice Cream            72.45  ...
# 97   Peanut Butter Cookies with Flax Seeds and Choc...            18.14  ...
# 37                    Roasted Asparagus with Egg Salad           217.78  ...
# 93           Roasted Strawberry Coconut Milk Ice Cream           143.71  ...
# 148  Sautéed Balsamic Green Beans With Cherry Tomatoes           101.81  ...
# 57   Sautéed Balsamic Green Beans With Cherry Tomatoes           101.81  ...
# 123                               Seasonal Autumn Stew           172.76  ...
# 14                          Spicy Carrot Amaranth Soup           220.53  ...
# 143                    Stir Fried Cabbage and Tomatoes            80.89  ...
# 133                            The Pearhattan Cocktail           509.89  ...
# 69                    Chicken with Avocado Peach Salsa            90.20  ...
# 31   Grilled Peach Melba with Vanilla Bean Frozen Y...           405.52  ...
# 61                            Ginger Melon Side Salad            219.70  ...
# 102                              Coconut Flour Muffins            30.66  ...
# 129  Blueberry, Persimmon Smoothie with Banana and ...            48.70  ...
# 126  Slow Cooker Healthy Sweet Potato Soup with Coc...           418.08  ...
# 134          Garlic-Roasted Brussels Sprouts Side Dish           170.34  ...
# 30                            Vegan Chana Masala Curry           165.89  ...
# 39                 Three Ingredient Frozen Pina Colada           214.60  ...
#
#      VitaminB3Amount  VitaminB3percentOfDailyNeed VitaminB1Amount  \
# 0               0.49                         2.44            0.03
# 1                NaN                          NaN             NaN
# 85              0.35                         1.77            0.03
# 100             0.84                         4.19            0.06
# 107             0.27                         1.35            0.02
# 96              0.67                         3.33            0.10
# 22              3.57                        17.83            0.20
# 147             4.77                        23.83            0.45
# 132             0.63                         3.15            0.19
# 101             0.29                         1.47            0.10
# 33              2.65                        13.26            0.35
# 27              2.02                        10.12            0.10
# 72              1.44                         7.19            0.24
# 20              0.90                         4.50            0.06
# 119             7.06                        35.32            0.42
# 24              1.28                         6.42            0.15
# 149             0.21                         1.05             NaN
# 106             0.24                         1.20            0.03
# 29              2.03                        10.15            0.19
# 139             0.76                         3.79            0.14
# 80              1.77                         8.87            0.19
# 131             0.85                         4.24            0.10
# 15              2.91                        14.54            0.23
# 42              0.97                         4.84            0.04
# 97              1.54                         7.68            0.04
# 37              2.17                        10.85            0.23
# 93              0.83                         4.14            0.03
# 148             1.15                         5.73            0.12
# 57              1.15                         5.73            0.12
# 123             6.15                        30.77            0.38
# 14              1.19                         5.94            0.09
# 143             1.40                         7.02            0.19
# 133             1.09                         5.44            0.10
# 69              1.61                         8.04            0.06
# 31              1.33                         6.63            0.07
# 61              1.60                         8.02            0.15
# 102              NaN                          NaN             NaN
# 129             2.97                        14.85            0.06
# 126             2.00                         9.99            0.26
# 134             1.23                         6.13            0.23
# 30              2.14                        10.71            0.20
# 39              1.05                         5.25            0.19
#
#      VitaminB1percentOfDailyNeed  CalciumAmount  CalciumpercentOfDailyNeed  \
# 0                           2.26          18.11                       1.81
# 1                            NaN            NaN                        NaN
# 85                          2.07          37.69                       3.77
# 100                         3.92          87.36                       8.74
# 107                         1.56          16.49                       1.65
# 96                          6.94         103.44                      10.34
# 22                         13.23          91.18                       9.12
# 147                        29.70         141.16                      14.12
# 132                        12.82         472.85                      47.29
# 101                         6.80          19.65                       1.96
# 33                         23.48         168.53                      16.85
# 27                          6.86         156.77                      15.68
# 72                         16.11          32.02                       3.20
# 20                          3.71          34.28                       3.43
# 119                        27.99         140.79                      14.08
# 24                         10.04          73.38                       7.34
# 149                          NaN          27.96                       2.80
# 106                         1.80          19.32                       1.93
# 29                         12.73          21.56                       2.16
# 139                         9.32         286.72                      28.67
# 80                         12.85         751.79                      75.18
# 131                         6.53         163.17                      16.32
# 15                         15.26          46.57                       4.66
# 42                          2.41          32.64                       3.26
# 97                          2.57          12.88                       1.29
# 37                         15.32         150.39                      15.04
# 93                          2.32          26.76                       2.68
# 148                         7.85          55.64                       5.56
# 57                          7.85          55.64                       5.56
# 123                        25.44         213.53                      21.35
# 14                          5.91         103.27                      10.33
# 143                        12.73         110.71                      11.07
# 133                         6.92          63.01                       6.30
# 69                          3.75          14.21                       1.42
# 31                          4.70         184.10                      18.41
# 61                          9.86          31.29                       3.13
# 102                          NaN            NaN                        NaN
# 129                         3.78          59.51                       5.95
# 126                        17.24         104.01                      10.40
# 134                        15.57          83.41                       8.34
# 30                         13.09         154.27                      15.43
# 39                         12.66          52.87                       5.29
#
#      AlcoholAmount  AlcoholpercentOfDailyNeed  CaffeineAmount  \
# 0              NaN                        NaN             NaN
# 1              NaN                        NaN             NaN
# 85             NaN                        NaN             NaN
# 100            NaN                        NaN             NaN
# 107           1.25                       6.96             NaN
# 96             NaN                        NaN             NaN
# 22             NaN                        NaN             NaN
# 147            NaN                        NaN             NaN
# 132           1.03                       5.73             NaN
# 101            NaN                        NaN             NaN
# 33             NaN                        NaN             NaN
# 27             NaN                        NaN             NaN
# 72             NaN                        NaN             NaN
# 20             NaN                        NaN             NaN
# 119            NaN                        NaN             NaN
# 24             NaN                        NaN             NaN
# 149            NaN                        NaN             NaN
# 106            NaN                        NaN             NaN
# 29             NaN                        NaN             NaN
# 139            NaN                        NaN             NaN
# 80             NaN                        NaN             NaN
# 131            NaN                        NaN             NaN
# 15             NaN                        NaN             NaN
# 42             NaN                        NaN             NaN
# 97             NaN                        NaN             NaN
# 37             NaN                        NaN             NaN
# 93             NaN                        NaN             NaN
# 148            NaN                        NaN             NaN
# 57             NaN                        NaN             NaN
# 123            NaN                        NaN             NaN
# 14             NaN                        NaN             NaN
# 143            NaN                        NaN             NaN
# 133          21.31                     118.40             NaN
# 69             NaN                        NaN             NaN
# 31             NaN                        NaN             NaN
# 61             NaN                        NaN             NaN
# 102            NaN                        NaN             NaN
# 129            NaN                        NaN             NaN
# 126            NaN                        NaN             NaN
# 134            NaN                        NaN             NaN
# 30             NaN                        NaN             NaN
# 39           13.36                      74.22             NaN
#
#      CaffeinepercentOfDailyNeed
# 0                           NaN
# 1                           NaN
# 85                          NaN
# 100                         NaN
# 107                         NaN
# 96                          NaN
# 22                          NaN
# 147                         NaN
# 132                         NaN
# 101                         NaN
# 33                          NaN
# 27                          NaN
# 72                          NaN
# 20                          NaN
# 119                         NaN
# 24                          NaN
# 149                         NaN
# 106                         NaN
# 29                          NaN
# 139                         NaN
# 80                          NaN
# 131                         NaN
# 15                          NaN
# 42                          NaN
# 97                          NaN
# 37                          NaN
# 93                          NaN
# 148                         NaN
# 57                          NaN
# 123                         NaN
# 14                          NaN
# 143                         NaN
# 133                         NaN
# 69                          NaN
# 31                          NaN
# 61                          NaN
# 102                         NaN
# 129                         NaN
# 126                         NaN
# 134                         NaN
# 30                          NaN
# 39                          NaN
#
# [42 rows x 79 columns]

# %% [markdown]
# #### How many vegan recipes are there (Vegan = Vegetarian and dairy free)?

# %%
maskvegan=df.vegetarian&df.dairyFree
df[maskvegan].shape[0]
# Out:
# 29

# %% [markdown]
# #### Compare the average amount of Vitamin B12 for the vegan and non-vegan recipes. How reliable are the results?

# %%
df[maskvegan].VitaminB12Amount.mean()
# Out:
# 0.24333333333333332

# %%
df[~maskvegan].VitaminB12Amount.mean()
# Out:
# 1.0345555555555557

# %% [markdown]
# #### Compare the average health Score for both types of recipes (vegan vs non-vegan).

# %%
df[maskvegan].healthScore.mean()
# Out:
# 27.724137931034484

# %%
df[~maskvegan].healthScore.mean()
# Out:
# 18.785123966942148

# %% [markdown]
# #### Create a new column: "VeganWeek" where you decrease the price of vegan products by 10%, but only if they already cost more than 100.

# %% [markdown]
# #### Among the non-vegan recipes, find the one requiring most time to prepare. How is it called?

# %%
df_nonvegan = df[~maskvegan]
df_nonvegan.loc[df["readyInMinutes"].idxmax()].title
# Out:
# 'Oeufs En Meurette'

# %%
df["readyInMinutes"]
# Out:
# 83     328
# 43      40
# 104     45
# 95      45
# 52      45
#       ...
# 134     35
# 30      30
# 118     45
# 39       5
# 67      40
# Name: readyInMinutes, Length: 150, dtype: int64
